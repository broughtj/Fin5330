# %% [markdown]
# # Help with HWK2
#
# <br>
#
# Feb. 28, 2019
#
# <br>

# %% [markdown]
# ## Problem 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
N = 500
y = np.cumsum(np.random.normal(size=N))
ts1 = pd.Series(y)
ts1.plot(grid=True, color="purple")

# %%
x = np.cumsum(np.random.normal(size=N))

# %%
ts2 = pd.Series(x)
ts2.plot(grid=True, color="orange")

# %%
import scipy.stats as stats

# %%
reg = stats.linregress(x,y)

# %%
reg
# Out:
# LinregressResult(slope=0.9843743757801412, intercept=-10.594082815307361, rvalue=0.46216871132322346, pvalue=7.9507771976891655e-28, stderr=0.08463828665285522)

# %%
reg[2] * reg[2]
# Out:
# 0.21359991772616907

# %%
reg[3]
# Out:
# 7.9507771976891655e-28

# %%
whos
# Out:
# Variable   Type                Data/Info
# ----------------------------------------
# N          int                 500
# np         module              <module 'numpy' from '/ho<...>kages/numpy/__init__.py'>
# pd         module              <module 'pandas' from '/h<...>ages/pandas/__init__.py'>
# plt        module              <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# reg        LinregressResult    LinregressResult(slope=0.<...>derr=0.08463828665285522)
# stats      module              <module 'scipy.stats' fro<...>scipy/stats/__init__.py'>
# ts1        Series              0       1.655243\n1      <...>ngth: 500, dtype: float64
# ts2        Series              0     -0.993249\n1     -0<...>ngth: 500, dtype: float64
# x          ndarray             500: 500 elems, type `float64`, 4000 bytes
# y          ndarray             500: 500 elems, type `float64`, 4000 bytes

# %%
reg.slope
# Out:
# 0.9843743757801412

# %%
N = 500
M = 50000
beta = np.empty(M)
rsqr = np.empty(M)

for i in range(M):
    y = np.cumsum(np.random.normal(size=N))
    x = np.cumsum(np.random.normal(size=N))
    reg = stats.linregress(x,y)
    beta[i] = reg.slope
    rsqr[i] = reg.rvalue ** 2

# %%
plt.hist(beta, bins=50);

# %%
plt.hist(rsqr, bins=50);

# %%
N = 500
a = 0.22
b = 2.5


# cointegration dgp
u = np.random.normal(size=N)
x = np.cumsum(np.random.normal(size=N))
y = a + b * x + u
reg = stats.linregress(x,y)

Dy = y[1:] - y[:-1]
Dx = x[1:] - x[:-1]
z = y - reg.intercept - reg.slope * x

# %%
Dy.shape
# Out:
# (499,)

# %%
Dx.shape
# Out:
# (499,)

# %%
z.shape
# Out:
# (500,)

# %%
Dy = Dy[1:]
Dx = Dx[1:]
z = z[2:]
X = np.ones((N-2,4))
X[:,1] = z
X[:,2] = Dy
X[:,3] = Dx
Y = Dy

# Run regression of Y on X

# %%
X.shape
# Out:
# (498, 4)
